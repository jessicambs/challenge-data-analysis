# %%
import pandas as pd

# %%
datas = pd.read_csv('database.csv')
datas.head()
# Out:
#    Unnamed: 0                                                Url  \
# 0           0  https://www.logic-immo.be/fr/vente/appartement...
# 1           1  https://www.logic-immo.be/fr/vente/appartement...
# 2           2  https://www.logic-immo.be/fr/vente/appartement...
# 3           3  https://www.logic-immo.be/fr/vente/appartement...
# 4           4  https://www.logic-immo.be/fr/vente/appartement...
#
#           Source  Locality Type of property Subtype of property     Price  \
# 0  logic-immo.be      2970        apartment                 NaN  319799.0
# 1  logic-immo.be      2970        apartment                 NaN  291999.0
# 2  logic-immo.be      2970        apartment                 NaN  764999.0
# 3  logic-immo.be      2970        apartment                 NaN  660264.0
# 4  logic-immo.be      3200        apartment                 NaN  294999.0
#
#    Type of sale  Number of rooms   Area  ...  Open fire  Terrace  \
# 0  regular sale              1.0    NaN  ...        0.0      1.0
# 1  regular sale              1.0    NaN  ...        0.0      1.0
# 2  regular sale              2.0  153.0  ...        0.0      1.0
# 3  regular sale              3.0    NaN  ...        0.0      1.0
# 4  regular sale              2.0   80.0  ...        0.0      0.0
#
#    Terrace Area  Garden  Garden Area  Surface of the land  \
# 0          11.0     0.0          NaN                  NaN
# 1           6.0     0.0          NaN                  NaN
# 2          62.0     0.0          NaN                  NaN
# 3         160.0     0.0          NaN                  NaN
# 4           NaN     0.0          NaN                  NaN
#
#    Surface area of the plot of land  Number of facades  Swimming pool  \
# 0                               NaN                NaN            0.0
# 1                               NaN                NaN            0.0
# 2                               NaN                NaN            0.0
# 3                               NaN                NaN            0.0
# 4                               NaN                NaN            0.0
#
#    State of the building
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 22 columns]

# %%
datas.drop(columns=['Unnamed: 0'], inplace=True)
datas.head()
# Out:
#                                                  Url         Source  Locality  \
# 0  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 1  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 2  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 3  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 4  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      3200
#
#   Type of property Subtype of property     Price  Type of sale  \
# 0        apartment                 NaN  319799.0  regular sale
# 1        apartment                 NaN  291999.0  regular sale
# 2        apartment                 NaN  764999.0  regular sale
# 3        apartment                 NaN  660264.0  regular sale
# 4        apartment                 NaN  294999.0  regular sale
#
#    Number of rooms   Area  Fully equipped kitchen  ...  Open fire  Terrace  \
# 0              1.0    NaN                     0.0  ...        0.0      1.0
# 1              1.0    NaN                     0.0  ...        0.0      1.0
# 2              2.0  153.0                     0.0  ...        0.0      1.0
# 3              3.0    NaN                     0.0  ...        0.0      1.0
# 4              2.0   80.0                     0.0  ...        0.0      0.0
#
#    Terrace Area  Garden  Garden Area  Surface of the land  \
# 0          11.0     0.0          NaN                  NaN
# 1           6.0     0.0          NaN                  NaN
# 2          62.0     0.0          NaN                  NaN
# 3         160.0     0.0          NaN                  NaN
# 4           NaN     0.0          NaN                  NaN
#
#    Surface area of the plot of land  Number of facades  Swimming pool  \
# 0                               NaN                NaN            0.0
# 1                               NaN                NaN            0.0
# 2                               NaN                NaN            0.0
# 3                               NaN                NaN            0.0
# 4                               NaN                NaN            0.0
#
#    State of the building
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 21 columns]

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73547 entries, 0 to 73546
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Source                            73547 non-null  object
#  1   Locality                          73547 non-null  int64
#  2   Type of property                  73167 non-null  object
#  3   Subtype of property               14730 non-null  object
#  4   Price                             72543 non-null  float64
#  5   Type of sale                      73547 non-null  object
#  6   Number of rooms                   72643 non-null  float64
#  7   Area                              62275 non-null  float64
#  8   Fully equipped kitchen            73547 non-null  float64
#  9   Furnished                         53506 non-null  float64
#  10  Open fire                         73547 non-null  float64
#  11  Terrace                           73547 non-null  float64
#  12  Terrace Area                      23283 non-null  float64
#  13  Garden                            73547 non-null  float64
#  14  Garden Area                       10998 non-null  float64
#  15  Surface of the land               34924 non-null  float64
#  16  Surface area of the plot of land  34924 non-null  float64
#  17  Number of facades                 35912 non-null  float64
#  18  Swimming pool                     73547 non-null  float64
#  19  State of the building             40529 non-null  object
# dtypes: float64(14), int64(1), object(5)
# memory usage: 11.2+ MB

# %%
datas = datas[~datas['Price'].isnull()]
datas.reset_index(inplace=True, drop=True)
datas.head()
# Out:
#                                                  Url         Source  Locality  \
# 0  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 1  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 2  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 3  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      2970
# 4  https://www.logic-immo.be/fr/vente/appartement...  logic-immo.be      3200
#
#   Type of property Subtype of property     Price  Type of sale  \
# 0        apartment                 NaN  319799.0  regular sale
# 1        apartment                 NaN  291999.0  regular sale
# 2        apartment                 NaN  764999.0  regular sale
# 3        apartment                 NaN  660264.0  regular sale
# 4        apartment                 NaN  294999.0  regular sale
#
#    Number of rooms   Area  Fully equipped kitchen  ...  Open fire  Terrace  \
# 0              1.0    NaN                     0.0  ...        0.0      1.0
# 1              1.0    NaN                     0.0  ...        0.0      1.0
# 2              2.0  153.0                     0.0  ...        0.0      1.0
# 3              3.0    NaN                     0.0  ...        0.0      1.0
# 4              2.0   80.0                     0.0  ...        0.0      0.0
#
#    Terrace Area  Garden  Garden Area  Surface of the land  \
# 0          11.0     0.0          NaN                  NaN
# 1           6.0     0.0          NaN                  NaN
# 2          62.0     0.0          NaN                  NaN
# 3         160.0     0.0          NaN                  NaN
# 4           NaN     0.0          NaN                  NaN
#
#    Surface area of the plot of land  Number of facades  Swimming pool  \
# 0                               NaN                NaN            0.0
# 1                               NaN                NaN            0.0
# 2                               NaN                NaN            0.0
# 3                               NaN                NaN            0.0
# 4                               NaN                NaN            0.0
#
#    State of the building
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 21 columns]

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72474 entries, 0 to 72473
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Locality                          72474 non-null  int64
#  1   Type of property                  72105 non-null  object
#  2   Subtype of property               14475 non-null  object
#  3   Price                             72474 non-null  float64
#  4   Type of sale                      72474 non-null  object
#  5   Number of rooms                   71678 non-null  float64
#  6   Area                              61504 non-null  float64
#  7   Fully equipped kitchen            72474 non-null  float64
#  8   Furnished                         52463 non-null  float64
#  9   Open fire                         72474 non-null  float64
#  10  Terrace                           72474 non-null  float64
#  11  Terrace Area                      23183 non-null  float64
#  12  Garden                            72474 non-null  float64
#  13  Garden Area                       10902 non-null  float64
#  14  Surface of the land               34593 non-null  float64
#  15  Surface area of the plot of land  34593 non-null  float64
#  16  Number of facades                 35815 non-null  float64
#  17  Swimming pool                     72474 non-null  float64
#  18  State of the building             40225 non-null  object
# dtypes: float64(14), int64(1), object(4)
# memory usage: 10.5+ MB

# %%
(datas.isnull().sum()/len(datas)).sort_values()
# Out:
# Source                              0.000000
# Locality                            0.000000
# Garden                              0.000000
# Type of sale                        0.000000
# Fully equipped kitchen              0.000000
# Swimming pool                       0.000000
# Open fire                           0.000000
# Terrace                             0.000000
# Type of property                    0.005167
# Number of rooms                     0.012291
# Price                               0.013651
# Area                                0.153263
# Furnished                           0.272492
# State of the building               0.448937
# Number of facades                   0.511714
# Surface of the land                 0.525147
# Surface area of the plot of land    0.525147
# Terrace Area                        0.683427
# Subtype of property                 0.799720
# Garden Area                         0.850463
# dtype: float64

# %%
(datas[datas['Type of property']=='house'].isnull().sum()/len(datas)).sort_values()
# Out:
# Source                              0.000000
# Locality                            0.000000
# Type of property                    0.000000
# Type of sale                        0.000000
# Fully equipped kitchen              0.000000
# Swimming pool                       0.000000
# Open fire                           0.000000
# Terrace                             0.000000
# Garden                              0.000000
# Number of rooms                     0.004446
# Price                               0.005534
# Surface area of the plot of land    0.040110
# Surface of the land                 0.040110
# Area                                0.107156
# Furnished                           0.152243
# Number of facades                   0.193971
# State of the building               0.203870
# Garden Area                         0.376576
# Subtype of property                 0.389560
# Terrace Area                        0.394414
# dtype: float64

# %%
(datas[datas['Type of property']=='apartment'].isnull().sum()/len(datas)).sort_values()
# Out:
# Source                              0.000000
# Locality                            0.000000
# Type of property                    0.000000
# Garden                              0.000000
# Type of sale                        0.000000
# Fully equipped kitchen              0.000000
# Swimming pool                       0.000000
# Open fire                           0.000000
# Terrace                             0.000000
# Number of rooms                     0.007546
# Price                               0.007968
# Area                                0.045073
# Furnished                           0.120250
# State of the building               0.241002
# Terrace Area                        0.284471
# Number of facades                   0.312725
# Subtype of property                 0.405972
# Garden Area                         0.469672
# Surface of the land                 0.483392
# Surface area of the plot of land    0.483392
# dtype: float64

# %%
datas.groupby('Type of property').size()
# Out:
# Type of property
# apartment    37235
# house        35932
# dtype: int64

# %%
small_data = datas.drop_duplicates()
print(small_data.shape)

datas.shape
# Out:
# (72543, 21)
# (72543, 21)

# %%
datas.drop(columns=['Source']).drop_duplicates().shape  #strange...
# Out:
# (73478, 19)

# %%
datas.drop(columns=['Source'], inplace=True)
datas.drop_duplicates(inplace=True)
datas.shape
# Out:
# (73478, 19)

# %%
datas=datas.astype({'Locality':'Int64', 
                  'Type of property':'string',
                  'Subtype of property':'string',
                  'Price':'float64', 
                  'Type of sale':'string',
                  'Number of rooms':'Int64', 
                  'Area':'float64', 
                  'Fully equipped kitchen':'Int64', 
                  'Furnished':'Int64',
                  'Open fire':'Int64',
                  'Terrace':'Int64',
                  'Terrace Area':'float64',
                  'Garden':'Int64',
                  'Garden Area':'float64',
                  'Surface of the land':'float64',
                  'Surface area of the plot of land':'float64',
                  'Number of facades':'Int64',
                  'Swimming pool':'Int64',
                  'State of the building':'string'
                 })
datas.dtypes
# Out:
# Locality                              Int64
# Type of property                     string
# Subtype of property                  string
# Price                               float64
# Type of sale                         string
# Number of rooms                       Int64
# Area                                float64
# Fully equipped kitchen                Int64
# Furnished                             Int64
# Open fire                             Int64
# Terrace                               Int64
# Terrace Area                        float64
# Garden                                Int64
# Garden Area                         float64
# Surface of the land                 float64
# Surface area of the plot of land    float64
# Number of facades                     Int64
# Swimming pool                         Int64
# State of the building                string
# dtype: object

# %%
datas['Type of property'] = datas['Type of property'].str.strip()
datas['Subtype of property'] = datas['Subtype of property'].str.strip()
datas['Type of sale'] = datas['Type of sale'].str.strip()
datas['State of the building'] = datas['State of the building'].str.strip()

# %%
datas['Type of property'].unique()
# Out:
# <StringArray>
# ['apartment', <NA>, 'house']
# Length: 3, dtype: string

# %%
datas['Subtype of property'].unique()
# Out:
# <StringArray>
# [                 <NA>,           'penthouse',            'building',
#               'studio',              'duplex',                'loft',
#         'ground floor',             'triplex',             'student',
#  'investment property',               'villa',             'mansion',
#                'mixed',      'apartments row',           'farmhouse',
#               'castle',               'floor',                'town',
#         'service flat',             'cottage',               'manor',
#             'pavilion']
# Length: 22, dtype: string

# %%
datas['Type of sale'].unique()
# Out:
# <StringArray>
# ['regular sale', 'public sale']
# Length: 2, dtype: string

# %%
datas['State of the building'].unique()
# Out:
# <StringArray>
# [<NA>, 'good', 'new', 'to renovate']
# Length: 4, dtype: string

# %%
datas['Price'].sort_values()
# Out:
# 42102       1.0
# 62106    2500.0
# 48665    2500.0
# 70109    2500.0
# 62099    2500.0
#           ...
# 63919       NaN
# 64136       NaN
# 66348       NaN
# 66971       NaN
# 66987       NaN
# Name: Price, Length: 73478, dtype: float64

# %%
datas['Number of rooms'].unique()
# Out:
# <IntegerArray>
# [   1,    2,    3, <NA>,   18,    4,    5,    6,   10,    7,  125,   14,    9,
#    32,   12,    8,   16,   19,   35,   11,   15,   13,   50,   20,   25,   70,
#    24,   21,   30,    0,  100,   47,   66,   22,   36,   40,   41,   34,   17,
#    28,   46,   63,  165,   27,   99,   37,   80,   39,   38,   90,   33,   23]
# Length: 52, dtype: Int64

# %%
datas['Number of rooms'].dropna().sort_values()
# Out:
# 35449      0
# 59655      0
# 71183      0
# 19153      0
# 59708      0
#         ...
# 62716     90
# 49953     99
# 19178    100
# 1582     125
# 43601    165
# Name: Number of rooms, Length: 72574, dtype: Int64

# %%
datas.loc[43601,:]
# Out:
# Locality                                    7300
# Type of property                           house
# Subtype of property                         <NA>
# Price                                     105000
# Type of sale                        regular sale
# Number of rooms                              165
# Area                                         165
# Fully equipped kitchen                         0
# Furnished                                      0
# Open fire                                      0
# Terrace                                        1
# Terrace Area                                 NaN
# Garden                                         0
# Garden Area                                  NaN
# Surface of the land                          537
# Surface area of the plot of land             537
# Number of facades                              3
# Swimming pool                                  0
# State of the building                to renovate
# Name: 43601, dtype: object

# %%
datas[datas[['Locality', 'Price', 'Type of property', 'Number of rooms', 'Area']].duplicated()]
# Out:
#        Locality Type of property Subtype of property     Price  Type of sale  \
# 14         9300        apartment            building       NaN  regular sale
# 183        1070        apartment                <NA>  394999.0  regular sale
# 191        1070        apartment                <NA>  394999.0  regular sale
# 201        1070        apartment                <NA>  394999.0  regular sale
# 218        1070        apartment                <NA>  334999.0  regular sale
# ...         ...              ...                 ...       ...           ...
# 73518      4620            house                <NA>  150000.0  regular sale
# 73526      9185            house                <NA>  340000.0  regular sale
# 73527      9185            house                <NA>  340000.0  regular sale
# 73538      9600            house                <NA>  315000.0  regular sale
# 73539      9600            house                <NA>  315000.0  regular sale
#
#        Number of rooms   Area  Fully equipped kitchen  Furnished  Open fire  \
# 14                <NA>    NaN                       0          0          0
# 183                  2  113.0                       0          0          0
# 191                  2  113.0                       0          0          0
# 201                  2  113.0                       0          0          0
# 218                  3  125.0                       0          0          0
# ...                ...    ...                     ...        ...        ...
# 73518                4  150.0                       0          0          0
# 73526                4  164.0                       0          0          0
# 73527                4  164.0                       0          0          0
# 73538                3  150.0                       0          0          0
# 73539                3  150.0                       0          0          0
#
#        Terrace  Terrace Area  Garden  Garden Area  Surface of the land  \
# 14           0           NaN       0          NaN                  NaN
# 183          1          77.0       0          NaN                  NaN
# 191          0           NaN       0          NaN                  NaN
# 201          0           NaN       0          NaN                  NaN
# 218          1          17.0       0          NaN                  NaN
# ...        ...           ...     ...          ...                  ...
# 73518        1           NaN       1         58.0                  0.0
# 73526        0           NaN       1        430.0                518.0
# 73527        0           NaN       1        429.0                518.0
# 73538        1           NaN       0          NaN                582.0
# 73539        1           NaN       0          NaN                610.0
#
#        Surface area of the plot of land  Number of facades  Swimming pool  \
# 14                                  NaN               <NA>              0
# 183                                 NaN               <NA>              0
# 191                                 NaN               <NA>              0
# 201                                 NaN               <NA>              0
# 218                                 NaN               <NA>              0
# ...                                 ...                ...            ...
# 73518                               0.0                  2              0
# 73526                             518.0                  3              0
# 73527                             518.0                  3              0
# 73538                             582.0                  3              0
# 73539                             610.0                  3              0
#
#       State of the building
# 14                     good
# 183                    <NA>
# 191                     new
# 201                    <NA>
# 218                    <NA>
# ...                     ...
# 73518                  <NA>
# 73526                  <NA>
# 73527                  <NA>
# 73538                  good
# 73539                  good
#
# [2930 rows x 19 columns]

# %%
datas.loc[73526,:]
# Out:
# Locality                                    9185
# Type of property                           house
# Subtype of property                         <NA>
# Price                                     340000
# Type of sale                        regular sale
# Number of rooms                                4
# Area                                         164
# Fully equipped kitchen                         0
# Furnished                                      0
# Open fire                                      0
# Terrace                                        0
# Terrace Area                                 NaN
# Garden                                         1
# Garden Area                                  430
# Surface of the land                          518
# Surface area of the plot of land             518
# Number of facades                              3
# Swimming pool                                  0
# State of the building                       <NA>
# Name: 73526, dtype: object

# %%
datas[(datas['Locality']==9185) & (datas['Price']==340000) & (datas['Type of property']=='house')
      & (datas['Number of rooms']==4) & (datas['Area']==164)]
# Out:
#        Locality Type of property Subtype of property     Price  Type of sale  \
# 73525      9185            house                <NA>  340000.0  regular sale
# 73526      9185            house                <NA>  340000.0  regular sale
# 73527      9185            house                <NA>  340000.0  regular sale
#
#        Number of rooms   Area  Fully equipped kitchen  Furnished  Open fire  \
# 73525                4  164.0                       0          0          0
# 73526                4  164.0                       0          0          0
# 73527                4  164.0                       0          0          0
#
#        Terrace  Terrace Area  Garden  Garden Area  Surface of the land  \
# 73525        0           NaN       1        446.0                534.0
# 73526        0           NaN       1        430.0                518.0
# 73527        0           NaN       1        429.0                518.0
#
#        Surface area of the plot of land  Number of facades  Swimming pool  \
# 73525                             534.0                  3              0
# 73526                             518.0                  3              0
# 73527                             518.0                  3              0
#
#       State of the building
# 73525                  <NA>
# 73526                  <NA>
# 73527                  <NA>

# %%
value = (datas['Locality'] == datas.loc[0, 'Locality']) | datas['Locality'].isnull()
duplicates_datas = []
for i in range(20000):
    value = (datas['Locality'] == datas.loc[i, 'Locality']) | datas['Locality'].isnull()
    for col in datas.columns:
        value = value & ((datas[col] == datas.loc[i, col]) | datas[col].isnull())
    if i%1000==0:
        print(i)
    if len(datas[value])>1:
        duplicates_datas.append(datas[value])
        
#logic immo has 19k datas
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000

# %%
len(duplicates_datas)
# Out:
# 1352

# %%
duplicates_datas[1300].head()
# Out:
#       Locality Type of property Subtype of property     Price  Type of sale  \
# 7548      8400        apartment                 NaN       NaN  regular sale
# 7757      8400        apartment                 NaN  344999.0  regular sale
#
#       Number of rooms   Area  Fully equipped kitchen  Furnished  Open fire  \
# 7548              2.0  101.0                     0.0        0.0        0.0
# 7757              2.0  101.0                     0.0        0.0        0.0
#
#       Terrace  Terrace Area  Garden  Garden Area  Surface of the land  \
# 7548      0.0           NaN     0.0          NaN                  NaN
# 7757      0.0           NaN     0.0          NaN                  NaN
#
#       Surface area of the plot of land  Number of facades  Swimming pool  \
# 7548                               NaN                NaN            1.0
# 7757                               NaN                NaN            1.0
#
#      State of the building
# 7548                  good
# 7757                  good

# %%
print(len(duplicates_datas))
duplicates_datas[0].head()
# Out:
# 490
#     Locality Type of property Subtype of property     Price  Type of sale  \
# 12      9300        apartment                 NaN  144999.0  regular sale
# 15      9300        apartment                 NaN  144999.0  regular sale
#
#     Number of rooms  Area  Fully equipped kitchen  Furnished  Open fire  \
# 12              1.0  70.0                     0.0        0.0        0.0
# 15              1.0   NaN                     0.0        0.0        0.0
#
#     Terrace  Terrace Area  Garden  Garden Area  Surface of the land  \
# 12      0.0           NaN     0.0          NaN                  NaN
# 15      0.0           NaN     0.0          NaN                  NaN
#
#     Surface area of the plot of land  Number of facades  Swimming pool  \
# 12                               NaN                NaN            0.0
# 15                               NaN                NaN            0.0
#
#    State of the building
# 12                   NaN
# 15                   NaN

# %%
duplicates_datas.sort(key=lambda x:x.index[-1], reverse=True)

# %%
duplicates_datas[3].head()
# Out:
#        Locality Type of property Subtype of property     Price  Type of sale  \
# 6126       7000        apartment                 NaN  214600.0  regular sale
# 67991      7000        apartment                 NaN  214600.0  regular sale
#
#        Number of rooms  Area  Fully equipped kitchen  Furnished  Open fire  \
# 6126               2.0  97.0                     0.0        0.0        0.0
# 67991              2.0  97.0                     0.0        NaN        0.0
#
#        Terrace  Terrace Area  Garden  Garden Area  Surface of the land  \
# 6126       0.0           NaN     0.0          NaN                  NaN
# 67991      0.0           NaN     0.0          NaN                  NaN
#
#        Surface area of the plot of land  Number of facades  Swimming pool  \
# 6126                                NaN                NaN            0.0
# 67991                               NaN                NaN            0.0
#
#       State of the building
# 6126                    NaN
# 67991                   NaN

# %% [markdown]
# ## Data Analysis

# %%
df = pd.read_csv('database.csv')
df.head()
# Out:
#    Unnamed: 0                                                Url  \
# 0           0  https://www.logic-immo.be/fr/vente/appartement...
# 1           1  https://www.logic-immo.be/fr/vente/appartement...
# 2           2  https://www.logic-immo.be/fr/vente/appartement...
# 3           3  https://www.logic-immo.be/fr/vente/appartement...
# 4           4  https://www.logic-immo.be/fr/vente/appartement...
#
#           Source  Locality Type of property Subtype of property     Price  \
# 0  logic-immo.be      2970        apartment                 NaN  319799.0
# 1  logic-immo.be      2970        apartment                 NaN  291999.0
# 2  logic-immo.be      2970        apartment                 NaN  764999.0
# 3  logic-immo.be      2970        apartment                 NaN  660264.0
# 4  logic-immo.be      3200        apartment                 NaN  294999.0
#
#    Type of sale  Number of rooms   Area  ...  Open fire  Terrace  \
# 0  regular sale              1.0    NaN  ...        0.0      1.0
# 1  regular sale              1.0    NaN  ...        0.0      1.0
# 2  regular sale              2.0  153.0  ...        0.0      1.0
# 3  regular sale              3.0    NaN  ...        0.0      1.0
# 4  regular sale              2.0   80.0  ...        0.0      0.0
#
#    Terrace Area  Garden  Garden Area  Surface of the land  \
# 0          11.0     0.0          NaN                  NaN
# 1           6.0     0.0          NaN                  NaN
# 2          62.0     0.0          NaN                  NaN
# 3         160.0     0.0          NaN                  NaN
# 4           NaN     0.0          NaN                  NaN
#
#    Surface area of the plot of land  Number of facades  Swimming pool  \
# 0                               NaN                NaN            0.0
# 1                               NaN                NaN            0.0
# 2                               NaN                NaN            0.0
# 3                               NaN                NaN            0.0
# 4                               NaN                NaN            0.0
#
#    State of the building
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 22 columns]

# %%
#df.drop(columns=['Unnamed: 0', 'Url', 'Source'], inplace=True)
old_col=(df.columns)
new_col=[]
# rename column in a pythonic way
for item in old_col:
    item =item.lower()
    item= item.replace(' ','_')
    new_col.append(item)

df.columns=new_col
df.drop_duplicates(inplace=True)
df = df[~df['price'].isnull()]
df.reset_index(inplace=True, drop=True)
prices = df.pop('price')
df.insert(0, 'price', prices)
df.head()
# Out:
# <ipython-input-11-52b02a4dfe47>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
#       price  locality type_of_property subtype_of_property  type_of_sale  \
# 0  319799.0      2970        apartment                 NaN  regular sale
# 1  291999.0      2970        apartment                 NaN  regular sale
# 2  764999.0      2970        apartment                 NaN  regular sale
# 3  660264.0      2970        apartment                 NaN  regular sale
# 4  294999.0      3200        apartment                 NaN  regular sale
#
#    number_of_rooms   area  fully_equipped_kitchen  furnished  open_fire  \
# 0              1.0    NaN                     0.0        0.0        0.0
# 1              1.0    NaN                     0.0        0.0        0.0
# 2              2.0  153.0                     0.0        0.0        0.0
# 3              3.0    NaN                     0.0        0.0        0.0
# 4              2.0   80.0                     0.0        0.0        0.0
#
#    terrace  terrace_area  garden  garden_area  surface_of_the_land  \
# 0      1.0          11.0     0.0          NaN                  NaN
# 1      1.0           6.0     0.0          NaN                  NaN
# 2      1.0          62.0     0.0          NaN                  NaN
# 3      1.0         160.0     0.0          NaN                  NaN
# 4      0.0           NaN     0.0          NaN                  NaN
#
#    surface_area_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 0                               NaN                NaN            0.0
# 1                               NaN                NaN            0.0
# 2                               NaN                NaN            0.0
# 3                               NaN                NaN            0.0
# 4                               NaN                NaN            0.0
#
#   state_of_the_building
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, ax = plt.subplots(figsize=(10, 10))
ax = sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 10))
sns.heatmap(df[df['type_of_property']=='apartment'].corr(), ax=ax1)
sns.heatmap(df[df['type_of_property']=='house'].corr(), ax=ax2)
plt.show()

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price                               1.000000
# number_of_rooms                     0.381926
# surface_area_of_the_plot_of_land    0.193190
# surface_of_the_land                 0.193190
# swimming_pool                       0.187083
# number_of_facades                   0.164052
# open_fire                           0.144068
# terrace_area                        0.128406
# garden_area                         0.126986
# fully_equipped_kitchen              0.114011
# garden                              0.061975
# terrace                             0.051652
# area                                0.035359
# furnished                          -0.022109
# locality                           -0.127731
# Name: price, dtype: float64

# %%
df[df['type_of_property']=='apartment'].corr()['price'].sort_values(ascending=False)
# Out:
# price                               1.000000
# number_of_rooms                     0.321188
# terrace_area                        0.257836
# fully_equipped_kitchen              0.135950
# open_fire                           0.133675
# number_of_facades                   0.098858
# terrace                             0.088271
# surface_area_of_the_plot_of_land    0.070679
# surface_of_the_land                 0.070679
# garden_area                         0.061032
# swimming_pool                       0.057825
# garden                              0.027006
# area                                0.016649
# furnished                          -0.033005
# locality                           -0.082602
# Name: price, dtype: float64

# %%
df[df['type_of_property']=='house'].corr()['price'].sort_values(ascending=False)
# Out:
# price                               1.000000
# area                                0.556285
# number_of_rooms                     0.389175
# swimming_pool                       0.228705
# surface_area_of_the_plot_of_land    0.195631
# surface_of_the_land                 0.195631
# number_of_facades                   0.173101
# fully_equipped_kitchen              0.138577
# open_fire                           0.135628
# garden_area                         0.130774
# terrace_area                        0.073362
# terrace                             0.067882
# garden                              0.040312
# furnished                          -0.001047
# locality                           -0.184331
# Name: price, dtype: float64

# %%
from scipy.stats import pearsonr
df_corr = pd.DataFrame(columns=['corr', 'p-value'])
for i in range(len(df.columns)):
    col = df.columns[i]
    if i==0 or df[col].dtypes != 'float64':
        continue
    df_col = df[['price', col]].dropna()
    df_corr.loc[col]=(pearsonr(df_col['price'], df_col[col]))
df_corr.sort_values(by='corr', ascending=False)
# Out:
#                                       corr        p-value
# number_of_rooms                   0.381926   0.000000e+00
# surface_of_the_land               0.193190  4.355211e-288
# surface_area_of_the_plot_of_land  0.193190  4.355211e-288
# swimming_pool                     0.187083   0.000000e+00
# number_of_facades                 0.164052  1.761635e-214
# open_fire                         0.144068   0.000000e+00
# terrace_area                      0.128406   8.345563e-86
# garden_area                       0.126986   1.987816e-40
# fully_equipped_kitchen            0.114011  3.275796e-208
# garden                            0.061975   1.306895e-62
# terrace                           0.051652   5.187806e-44
# area                              0.035359   1.759659e-18
# furnished                        -0.022109   4.095584e-07

# %%
plt.scatter(df['number_of_rooms'], df['price'])
plt.show()

# %%
plt.scatter(df[df['number_of_rooms']<10]['number_of_rooms'], df[df['number_of_rooms']<10]['price'])

# %%
df_house = df[df['type_of_property']=='house']
df_corr = pd.DataFrame(columns=['corr', 'p-value'])
for i in range(len(df.columns)):
    col = df.columns[i]
    if i==0 or df_house[col].dtypes != 'float64':
        continue
    df_col = df_house[['price', col]].dropna()
    df_corr.loc[col]=(pearsonr(df_col['price'], df_col[col]))
df_corr.sort_values(by='corr', ascending=False)
# Out:
#                                       corr        p-value
# area                              0.556285   0.000000e+00
# number_of_rooms                   0.389175   0.000000e+00
# swimming_pool                     0.228705   0.000000e+00
# surface_of_the_land               0.195631  2.534586e-280
# surface_area_of_the_plot_of_land  0.195631  2.534586e-280
# number_of_facades                 0.173101  5.003284e-145
# fully_equipped_kitchen            0.138577  1.149101e-151
# open_fire                         0.135628  2.633495e-145
# garden_area                       0.130774   1.560703e-32
# terrace_area                      0.073362   1.080717e-09
# terrace                           0.067882   1.588333e-37
# garden                            0.040312   3.029803e-14
# furnished                        -0.001047   8.702606e-01

# %%
plt.scatter(df_house['area'], df_house['price'])

# %%
df_house_small = df_house[df_house['area']<2500]
plt.scatter(df_house_small['area'], df_house_small['price'])

# %%
df_apartment = df[df['type_of_property']=='apartment']
print(df_apartment['area'].isnull().sum()/len(df_apartment['area']))
df_corr = pd.DataFrame(columns=['corr', 'p-value'])
for i in range(len(df.columns)):
    col = df.columns[i]
    if i==0 or df_apartment[col].dtypes != 'float64':
        continue
    df_col = df_apartment[['price', col]].dropna()
    df_corr.loc[col]=(pearsonr(df_col['price'], df_col[col]))
df_corr.sort_values(by='corr', ascending=False)
# Out:
# 0.08728663116209204
#                                       corr        p-value
# number_of_rooms                   0.321188   0.000000e+00
# terrace_area                      0.257836  5.193711e-245
# fully_equipped_kitchen            0.135950  1.476158e-150
# open_fire                         0.133675  1.390464e-145
# number_of_facades                 0.098858   3.737407e-32
# terrace                           0.088271   3.038361e-64
# surface_of_the_land               0.070679   5.599389e-03
# surface_area_of_the_plot_of_land  0.070679   5.599389e-03
# garden_area                       0.061032   1.660718e-03
# swimming_pool                     0.057825   1.683128e-28
# garden                            0.027006   2.360893e-07
# area                              0.016649   2.337584e-03
# furnished                        -0.033005   3.750736e-08

# %%
from scipy.stats import spearmanr
df_corr = pd.DataFrame(columns=['spearmanr', 'p-value'])
for i in range(len(df.columns)):
    col = df.columns[i]
    if i==0 or df_house[col].dtypes != 'float64':
        continue
    df_col = df_house[['price', col]].dropna()
    df_corr.loc[col]=(spearmanr(df_col['price'], df_col[col]))
df_corr.sort_values(by='spearmanr', ascending=False)
# Out:
#                                   spearmanr        p-value
# area                               0.662162   0.000000e+00
# number_of_rooms                    0.452373   0.000000e+00
# surface_of_the_land                0.393866   0.000000e+00
# surface_area_of_the_plot_of_land   0.393866   0.000000e+00
# number_of_facades                  0.297498   0.000000e+00
# garden_area                        0.268896  1.719500e-135
# terrace_area                       0.247399   1.278481e-96
# fully_equipped_kitchen             0.222875   0.000000e+00
# swimming_pool                      0.183269  1.226215e-265
# open_fire                          0.182269  1.006770e-262
# terrace                            0.132230  3.743320e-138
# garden                             0.112628  1.571027e-100
# furnished                         -0.028272   1.037978e-05

# %% [markdown]
# # values by municipalities and region

# %%
df_cities = pd.read_csv('/home/nathanael/Documents/BeCode/Projects/Data_Analysis/challenge-data-analysis/DataCleaning/post_codes.csv', sep=';')
print(df_cities.shape)
df_cities.head()
# Out:
# (2825, 5)
#    Code postal  Localité Sous-commune Commune principale             Province
# 0         8511   Aalbeke          Oui           KORTRIJK  Flandre-Occidentale
# 1         3200  AARSCHOT          Non           AARSCHOT      Brabant Flamand
# 2         5590    Achêne          Oui              CINEY                Namur
# 3         6250    Aiseau          Oui     AISEAU-PRESLES              Hainaut
# 4         7640   ANTOING          Non            ANTOING              Hainaut

# %%
province = {'province' : ['Flandre-Occidentale', 'Brabant Flamand', 'Namur', 'Hainaut',
       'Luxembourg', 'Flandre-Orientale', 'Liège', 'Limbourg',
       'Brabant Wallon', np.nan, 'Anvers', 'Bruxelles (19 communes)'],
           'region' : ['Flandre', 'Flandre', 'Wallonie', 'Wallonie', 'Wallonie', 'Flandre', 'Wallonie', 'Flandre',
                       'Wallonie', np.nan, 'Flandre', 'Bruxelles'
                      ]}
df_province = pd.DataFrame(province)
df_province
# Out:
#                    province     region
# 0       Flandre-Occidentale    Flandre
# 1           Brabant Flamand    Flandre
# 2                     Namur   Wallonie
# 3                   Hainaut   Wallonie
# 4                Luxembourg   Wallonie
# 5         Flandre-Orientale    Flandre
# 6                     Liège   Wallonie
# 7                  Limbourg    Flandre
# 8            Brabant Wallon   Wallonie
# 9                       NaN        NaN
# 10                   Anvers    Flandre
# 11  Bruxelles (19 communes)  Bruxelles

# %%
df_cities = df_cities.merge(df_province, how= 'left', left_on='Province', right_on='province')
df_cities.head()
# Out:
# (2825, 7)
#    Code postal  Localité Sous-commune Commune principale             Province  \
# 0         8511   Aalbeke          Oui           KORTRIJK  Flandre-Occidentale
# 1         3200  AARSCHOT          Non           AARSCHOT      Brabant Flamand
# 2         5590    Achêne          Oui              CINEY                Namur
# 3         6250    Aiseau          Oui     AISEAU-PRESLES              Hainaut
# 4         7640   ANTOING          Non            ANTOING              Hainaut
#
#               province    region
# 0  Flandre-Occidentale   Flandre
# 1      Brabant Flamand   Flandre
# 2                Namur  Wallonie
# 3              Hainaut  Wallonie
# 4              Hainaut  Wallonie

# %%
df_with_region = df.merge(df_cities[['Code postal', 'region']], how='left', left_on='locality', right_on='Code postal')
df_with_region.drop_duplicates(inplace=True)
df_with_region.head()
# Out:
#       price  locality type_of_property subtype_of_property  type_of_sale  \
# 0  319799.0      2970        apartment                 NaN  regular sale
# 2  291999.0      2970        apartment                 NaN  regular sale
# 4  764999.0      2970        apartment                 NaN  regular sale
# 6  660264.0      2970        apartment                 NaN  regular sale
# 8  294999.0      3200        apartment                 NaN  regular sale
#
#    number_of_rooms   area  fully_equipped_kitchen  furnished  open_fire  ...  \
# 0              1.0    NaN                     0.0        0.0        0.0  ...
# 2              1.0    NaN                     0.0        0.0        0.0  ...
# 4              2.0  153.0                     0.0        0.0        0.0  ...
# 6              3.0    NaN                     0.0        0.0        0.0  ...
# 8              2.0   80.0                     0.0        0.0        0.0  ...
#
#    terrace_area  garden  garden_area  surface_of_the_land  \
# 0          11.0     0.0          NaN                  NaN
# 2           6.0     0.0          NaN                  NaN
# 4          62.0     0.0          NaN                  NaN
# 6         160.0     0.0          NaN                  NaN
# 8           NaN     0.0          NaN                  NaN
#
#    surface_area_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 0                               NaN                NaN            0.0
# 2                               NaN                NaN            0.0
# 4                               NaN                NaN            0.0
# 6                               NaN                NaN            0.0
# 8                               NaN                NaN            0.0
#
#    state_of_the_building Code postal   region
# 0                    NaN      2970.0  Flandre
# 2                    NaN      2970.0  Flandre
# 4                    NaN      2970.0  Flandre
# 6                    NaN      2970.0  Flandre
# 8                    NaN      3200.0  Flandre
#
# [5 rows x 21 columns]

# %%
df_with_region = df_with_region[['price', 'locality', 'region', 'type_of_property']]
df_with_region['price_per_m_square'] = df['price']/df['area']
df_with_region['area'] = df['area']
df_with_region.head()
# Out:
#       price  locality   region type_of_property  price_per_m_square   area
# 0  319799.0      2970  Flandre        apartment                 NaN    NaN
# 2  291999.0      2970  Flandre        apartment         4999.993464  153.0
# 4  764999.0      2970  Flandre        apartment         3687.487500   80.0
# 6  660264.0      2970  Flandre        apartment         2599.988889   90.0
# 8  294999.0      3200  Flandre        apartment                 NaN    NaN

# %%
df_with_region.groupby('region').agg(['mean','median'])[['price', 'price_per_m_square', 'area']]
# Out:
#                    price           price_per_m_square               \
#                     mean    median               mean       median
# region
# Bruxelles  611432.077640  370749.5        2811.569425  2591.750842
# Flandre    375969.230396  291799.0        2684.508621  2443.609023
# Wallonie   278776.175270  224999.0        2760.105370  2398.373984
#
#                  area
#                  mean median
# region
# Bruxelles  144.155070  108.0
# Flandre    220.955805  120.0
# Wallonie   157.120049  121.0

# %%
df_with_region.groupby(['type_of_property','region']).agg(['mean','median'])[['price', 'price_per_m_square', 'area']]
# Out:
#                                    price           price_per_m_square  \
#                                     mean    median               mean
# type_of_property region
# apartment        Bruxelles  4.563736e+05  320000.0        2902.114409
#                  Flandre    3.284428e+05  265000.0        2749.655256
#                  Wallonie   2.402853e+05  217000.0        2898.555282
# house            Bruxelles  1.037578e+06  630000.0        2503.632833
#                  Flandre    4.306907e+05  329000.0        2602.438904
#                  Wallonie   2.992297e+05  229999.0        2669.885418
#
#                                                area
#                                  median        mean median
# type_of_property region
# apartment        Bruxelles  2649.983333  140.196254  104.0
#                  Flandre    2459.599967  155.647692  119.0
#                  Wallonie   2445.720430  152.394039  117.0
# house            Bruxelles  2371.428571  158.428110  125.0
#                  Flandre    2426.086957  306.692907  122.0
#                  Wallonie   2373.015873  160.736043  125.0

# %%
df_loc = df_with_region.groupby('locality').agg(['mean','median', 'size'])
df_loc = df_loc['price']
df_loc[df_loc['size']>2].sort_values(by= 'mean', ascending=False)
# Out:
#                   mean    median  size
# locality
# 1380      1.359240e+06  895000.0   137
# 1640      1.224902e+06  628999.0   103
# 7021      1.140106e+06  196999.0    47
# 1170      1.081651e+06  580000.0   125
# 2920      1.057028e+06  590000.0    29
# ...                ...       ...   ...
# 4602      1.336992e+05  131999.0    10
# 7340      1.316284e+05  120000.0   127
# 6440      1.269279e+05   92499.0    14
# 7024      1.148325e+05  109499.0     6
# 5542      9.537475e+04   94250.0     4
#
# [860 rows x 3 columns]

# %%
df_loc = df_with_region.groupby('locality').agg(['mean','median', 'size'])
df_loc[df_loc['price_per_m_square']['size']>2].sort_values(by= ('price_per_m_square','mean'), ascending=False)
# Out:
#                   price                price_per_m_square                     \
#                    mean    median size               mean        median size
# locality
# 5001      301475.823529  305199.0   17       44516.032992   2680.491991   17
# 7534      306250.000000  290000.0    4       17272.727273  17272.727273    4
# 1348      373647.288210  384000.0  229       11603.410787   3372.113365  229
# 9930      414794.117647  365000.0   17       11383.257031  11383.257031   17
# 3221      342750.000000  352500.0    8       10102.040816  10102.040816    8
# ...                 ...       ...  ...                ...           ...  ...
# 8640      299731.500000  234960.0    8                NaN           NaN    8
# 9968      327250.000000  333750.0   10                NaN           NaN   10
# 9980      303942.428571  292597.0    7                NaN           NaN    7
# 9988      422000.000000  387000.0    4                NaN           NaN    4
# 9994      397765.500000  419755.5    4                NaN           NaN    4
#
#                 area
#                 mean median size
# locality
# 5001      138.400000  114.0   17
# 7534      132.000000  132.0    4
# 1348      305.691176  255.0  229
# 9930      113.500000  113.5   17
# 3221       98.000000   98.0    8
# ...              ...    ...  ...
# 8640             NaN    NaN    8
# 9968             NaN    NaN   10
# 9980             NaN    NaN    7
# 9988             NaN    NaN    4
# 9994             NaN    NaN    4
#
# [860 rows x 9 columns]

# %%
df_with_province = df.merge(df_cities[['Code postal', 'province']], how='left', left_on='locality', right_on='Code postal')
df_with_province.drop_duplicates(inplace=True)
df_with_province = df_with_province[['price', 'locality', 'province']]
df_with_province.head()
# Out:
#       price  locality         province
# 0  319799.0      2970           Anvers
# 2  291999.0      2970           Anvers
# 4  764999.0      2970           Anvers
# 6  660264.0      2970           Anvers
# 8  294999.0      3200  Brabant Flamand

# %%
df_with_province.groupby('province').agg(['mean','median'])['price'].sort_values(by='mean', ascending=False)
# Out:
#                                   mean    median
# province
# Bruxelles (19 communes)  611432.077640  370749.5
# Brabant Wallon           434127.660359  325000.0
# Brabant Flamand          420970.581020  325000.0
# Anvers                   396779.305180  299000.0
# Flandre-Occidentale      373878.341682  280000.0
# Flandre-Orientale        355701.019404  296513.0
# Limbourg                 318555.687690  269000.0
# Luxembourg               277535.805488  239000.0
# Namur                    270861.753310  240000.0
# Liège                    263876.098909  228999.0
# Hainaut                  240375.416783  189900.0

# %%
df_with_province = df.merge(df_cities[['Code postal', 'province']], how='left', left_on='locality', right_on='Code postal')
df_with_province.drop_duplicates(inplace=True)
df_with_province = df_with_province[['price', 'locality', 'province', 'type_of_property']]
df_with_province.head()
# Out:
#       price  locality         province type_of_property
# 0  319799.0      2970           Anvers        apartment
# 2  291999.0      2970           Anvers        apartment
# 4  764999.0      2970           Anvers        apartment
# 6  660264.0      2970           Anvers        apartment
# 8  294999.0      3200  Brabant Flamand        apartment

# %%
df_with_province.groupby(['type_of_property', 'province']).agg(['mean','std', 'median'])['price'].sort_values(by='mean', ascending=False)
# Out:
#                                                   mean           std    median
# type_of_property province
# house            Bruxelles (19 communes)  1.037578e+06  1.325433e+06  630000.0
#                  Brabant Wallon           5.728406e+05  6.308051e+05  394999.0
#                  Brabant Flamand          5.184300e+05  4.948942e+05  385558.5
#                  Anvers                   4.976614e+05  4.731815e+05  364000.0
# apartment        Bruxelles (19 communes)  4.563736e+05  4.397273e+05  320000.0
# house            Flandre-Occidentale      4.033548e+05  4.015536e+05  299000.0
#                  Flandre-Orientale        3.958770e+05  3.182488e+05  329000.0
#                  Limbourg                 3.543660e+05  2.672512e+05  295000.0
# apartment        Flandre-Occidentale      3.524378e+05  3.440802e+05  264999.0
#                  Brabant Flamand          3.244489e+05  2.289159e+05  275000.0
#                  Anvers                   3.143146e+05  2.313053e+05  265000.0
#                  Brabant Wallon           3.120590e+05  1.428808e+05  279000.0
#                  Flandre-Orientale        3.096168e+05  1.730766e+05  268999.5
# house            Luxembourg               2.998904e+05  1.879654e+05  255000.0
#                  Namur                    2.906181e+05  1.989294e+05  252500.0
# apartment        Limbourg                 2.817607e+05  1.692646e+05  247424.5
# house            Liège                    2.815727e+05  2.288038e+05  239000.0
#                  Hainaut                  2.518019e+05  4.127312e+05  189900.0
# apartment        Liège                    2.332253e+05  1.032836e+05  218499.5
#                  Namur                    2.253116e+05  1.053894e+05  215000.0
#                  Luxembourg               2.227712e+05  8.247066e+04  215000.0
#                  Hainaut                  2.108160e+05  1.053211e+05  189000.0

# %%
df_supp = df
df_supp['area_inv'] = 1/df['area']
df_supp.corr()['price']
# Out:
# price                               1.000000
# locality                           -0.127731
# number_of_rooms                     0.381926
# area                                0.035359
# fully_equipped_kitchen              0.114011
# furnished                          -0.022109
# open_fire                           0.144068
# terrace                             0.051652
# terrace_area                        0.128406
# garden                              0.061975
# garden_area                         0.126986
# surface_of_the_land                 0.193190
# surface_area_of_the_plot_of_land    0.193190
# number_of_facades                   0.164052
# swimming_pool                       0.187083
# area_inv                           -0.234439
# Name: price, dtype: float64

# %%
df_with_province.groupby(['type_of_property', 'province']).describe()['price'].sort_values(by='mean', ascending=False)
# Out:
#                                            count          mean           std  \
# type_of_property province
# house            Bruxelles (19 communes)  2001.0  1.037578e+06  1.325433e+06
#                  Brabant Wallon           1404.0  5.728406e+05  6.308051e+05
#                  Brabant Flamand          2648.0  5.184300e+05  4.948942e+05
#                  Anvers                   3636.0  4.976614e+05  4.731815e+05
# apartment        Bruxelles (19 communes)  5667.0  4.563736e+05  4.397273e+05
# house            Flandre-Occidentale      6580.0  4.033548e+05  4.015536e+05
#                  Flandre-Orientale        4860.0  3.958770e+05  3.182488e+05
#                  Limbourg                 1661.0  3.543660e+05  2.672512e+05
# apartment        Flandre-Occidentale      9655.0  3.524378e+05  3.440802e+05
#                  Brabant Flamand          2668.0  3.244489e+05  2.289159e+05
#                  Anvers                   4501.0  3.143146e+05  2.313053e+05
#                  Brabant Wallon           1651.0  3.120590e+05  1.428808e+05
#                  Flandre-Orientale        4350.0  3.096168e+05  1.730766e+05
# house            Luxembourg                880.0  2.998904e+05  1.879654e+05
#                  Namur                    1403.0  2.906181e+05  1.989294e+05
# apartment        Limbourg                 1618.0  2.817607e+05  1.692646e+05
# house            Liège                    4035.0  2.815727e+05  2.288038e+05
#                  Hainaut                  6355.0  2.518019e+05  4.127312e+05
# apartment        Liège                    2656.0  2.332253e+05  1.032836e+05
#                  Namur                     629.0  2.253116e+05  1.053894e+05
#                  Luxembourg                357.0  2.227712e+05  8.247066e+04
#                  Hainaut                  2853.0  2.108160e+05  1.053211e+05
#
#                                               min       25%       50%  \
# type_of_property province
# house            Bruxelles (19 communes)  20000.0  400000.0  630000.0
#                  Brabant Wallon           30000.0  279000.0  394999.0
#                  Brabant Flamand           2500.0  299000.0  385558.5
#                  Anvers                   25000.0  285000.0  364000.0
# apartment        Bruxelles (19 communes)      1.0  229000.0  320000.0
# house            Flandre-Occidentale      10000.0  245000.0  299000.0
#                  Flandre-Orientale        25000.0  259000.0  329000.0
#                  Limbourg                 17500.0  239000.0  295000.0
# apartment        Flandre-Occidentale       2500.0  199000.0  264999.0
#                  Brabant Flamand          79000.0  229000.0  275000.0
#                  Anvers                   55000.0  217000.0  265000.0
#                  Brabant Wallon           30000.0  232824.5  279000.0
#                  Flandre-Orientale        10000.0  220000.0  268999.5
# house            Luxembourg               19000.0  175000.0  255000.0
#                  Namur                    22000.0  178000.0  252500.0
# apartment        Limbourg                 73500.0  209000.0  247424.5
# house            Liège                     2500.0  169949.5  239000.0
#                  Hainaut                  10000.0  130000.0  189900.0
# apartment        Liège                    33500.0  178000.0  218499.5
#                  Namur                    50000.0  165000.0  215000.0
#                  Luxembourg               64000.0  173999.0  215000.0
#                  Hainaut                  20000.0  155000.0  189000.0
#
#                                                  75%         max
# type_of_property province
# house            Bruxelles (19 communes)  1200000.00  35000000.0
#                  Brabant Wallon            589999.25   6500000.0
#                  Brabant Flamand           525000.00   9500000.0
#                  Anvers                    499000.00   5900000.0
# apartment        Bruxelles (19 communes)   496999.50   5200000.0
# house            Flandre-Occidentale       396269.25   8500000.0
#                  Flandre-Orientale         422200.00   9876543.0
#                  Limbourg                  374000.00   3850000.0
# apartment        Flandre-Occidentale       369999.00   5300000.0
#                  Brabant Flamand           350000.00   3500000.0
#                  Anvers                    329000.00   3795000.0
#                  Brabant Wallon            370000.00   2250000.0
#                  Flandre-Orientale         348999.00   3700000.0
# house            Luxembourg                374925.00   1600000.0
#                  Namur                     334949.00   2600000.0
# apartment        Limbourg                  298063.75   3850000.0
# house            Liège                     325000.00   7490000.0
#                  Hainaut                   279499.50  15000000.0
# apartment        Liège                     260000.00   1099999.0
#                  Namur                     269999.00   1730000.0
#                  Luxembourg                258300.00    949999.0
#                  Hainaut                   235000.00   1299000.0

# %%
df.groupby(['type_of_property', 'locality']).size().mean()
# Out:
# 41.32091690544413

# %%
df_with_province.groupby(['type_of_property', 'province']).size().mean()
# Out:
# 3275.818181818182
